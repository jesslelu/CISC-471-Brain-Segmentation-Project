# %%
import numpy as np
import nibabel as nib
import glob
import pandas as pd
import random
import os

from matplotlib import pyplot as plt
from tifffile import imsave
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

from tensorflow.keras.utils import to_categorical

# %%
TRAIN_DATASET_PATH = 'data/training/'
TRAIN_PROCESSED_DATASET_PATH = 'processed-data/training/'
NAME_MAPPING_CSV = TRAIN_DATASET_PATH + 'name_mapping.csv'
train_df_nm = pd.read_csv(NAME_MAPPING_CSV)
#train_df_nm.head(5)

# %%
t1_img_list = sorted(glob.glob(TRAIN_DATASET_PATH+'/*/*t1.nii'))
t2_img_list = sorted(glob.glob(TRAIN_DATASET_PATH+'/*/*t2.nii'))
t1ce_img_list = sorted(glob.glob(TRAIN_DATASET_PATH+'/*/*t1ce.nii'))
flair_img_list = sorted(glob.glob(TRAIN_DATASET_PATH+'/*/*flair.nii'))
mask_img_list = sorted(glob.glob(TRAIN_DATASET_PATH+'/*/*seg.nii'))

# %%
""" Just Checking that it's scaling right.
temp_image_t2=nib.load(t2_list[0]).get_fdata()
temp_image_t2=scaler.fit_transform(temp_image_t2.reshape(-1, temp_image_t2.shape[-1])).reshape(temp_image_t2.shape)
data = pd.DataFrame({"t1": temp_image_t2.reshape(-1)})
ax = data[['t1']].plot(kind='box', title='Distribution of MRI scan Pixel Values Normalized + Cropped')
plt.show()
"""
# Out:
# ' Just Checking that it\'s scaling right.\ntemp_image_t2=nib.load(t2_list[0]).get_fdata()\ntemp_image_t2=scaler.fit_transform(temp_image_t2.reshape(-1, temp_image_t2.shape[-1])).reshape(temp_image_t2.shape)\ndata = pd.DataFrame({"t1": temp_image_t2.reshape(-1)})\nax = data[[\'t1\']].plot(kind=\'box\', title=\'Distribution of MRI scan Pixel Values Normalized + Cropped\')\nplt.show()\n'

# %%
for img in range(len(mask_img_list)): 
    print("Now processing: ", img)
    
    #Scaling pixel values
    t2_img=nib.load(t2_img_list[img]).get_fdata()
    t2_img=scaler.fit_transform(t2_img.reshape(-1, t2_img.shape[-1])).reshape(t2_img.shape)
   
    t1ce_img=nib.load(t1ce_img_list[img]).get_fdata()
    t1ce_img=scaler.fit_transform(t1ce_img.reshape(-1, t1ce_img.shape[-1])).reshape(t1ce_img.shape)
   
    flair_img=nib.load(flair_img_list[img]).get_fdata()
    flair_img=scaler.fit_transform(flair_img.reshape(-1, flair_img.shape[-1])).reshape(flair_img.shape)
        
    mask_img=nib.load(mask_img_list[img]).get_fdata()
    mask_img=mask_img.astype(np.uint8)
    mask_img[mask_img==4] = 3  #Assign mask values 4 to 3
    
    combined_images = np.stack([flair_img, t1ce_img, t2_img], axis=3)
    
    #Crop images and mask
    combined_images=combined_images[56:184, 56:184, 13:141]
    mask_img = mask_img[56:184, 56:184, 13:141]
    
    val, counts = np.unique(mask_img, return_counts=True)
    
    if (1 - (counts[0]/counts.sum())) > 0.01:  #At least 1% useful volume with labels that are not 0
        print("Saving")
        temp_mask= to_categorical(mask_img, num_classes=4)
        np.save(TRAIN_PROCESSED_DATASET_PATH+'/images/processed_img_'+str(img)+'.npy', combined_images)
        np.save(TRAIN_PROCESSED_DATASET_PATH+'/masks/processed_mask_'+str(img)+'.npy', mask_img)
        
    else:
        print("thrown out")
# Out:
# Now processing:  0
# Saving
# Now processing:  1
# Saving
# Now processing:  2
# Saving
# Now processing:  3
# Saving
# Now processing:  4
# thrown out
# Now processing:  5
# Saving
# Now processing:  6
# Saving
# Now processing:  7
# Saving
# Now processing:  8
# Saving
# Now processing:  9
# Saving
# Now processing:  10
# Saving
# Now processing:  11
# Saving
# Now processing:  12
# Saving
# Now processing:  13
# Saving
# Now processing:  14
# Saving
# Now processing:  15
# Saving
# Now processing:  16
# Saving
# Now processing:  17
# Saving
# Now processing:  18
# Saving
# Now processing:  19
# Saving
# Now processing:  20
# Saving
# Now processing:  21
# Saving
# Now processing:  22
# Saving
# Now processing:  23
# Saving
# Now processing:  24
# Saving
# Now processing:  25
# Saving
# Now processing:  26
# Saving
# Now processing:  27
# thrown out
# Now processing:  28
# Saving
# Now processing:  29
# Saving
# Now processing:  30
# Saving
# Now processing:  31
# Saving
# Now processing:  32
# Saving
# Now processing:  33
# Saving
# Now processing:  34
# Saving
# Now processing:  35
# thrown out
# Now processing:  36
# Saving
# Now processing:  37
# Saving
# Now processing:  38
# Saving
# Now processing:  39
# Saving
# Now processing:  40
# Saving
# Now processing:  41
# Saving
# Now processing:  42
# Saving
# Now processing:  43
# thrown out
# Now processing:  44
# Saving
# Now processing:  45
# Saving
# Now processing:  46
# Saving
# Now processing:  47
# Saving
# Now processing:  48
# Saving
# Now processing:  49
# Saving
# Now processing:  50
# Saving
# Now processing:  51
# Saving
# Now processing:  52
# Saving
# Now processing:  53
# Saving
# Now processing:  54
# Saving
# Now processing:  55
# Saving
# Now processing:  56
# Saving
# Now processing:  57
# Saving
# Now processing:  58
# Saving
# Now processing:  59
# Saving
# Now processing:  60
# thrown out
# Now processing:  61
# Saving
# Now processing:  62
# thrown out
# Now processing:  63
# Saving
# Now processing:  64
# Saving
# Now processing:  65
# Saving
# Now processing:  66
# Saving
# Now processing:  67
# Saving
# Now processing:  68
# Saving
# Now processing:  69
# Saving
# Now processing:  70
# Saving
# Now processing:  71
# Saving
# Now processing:  72
# Saving
# Now processing:  73
# Saving
# Now processing:  74
# Saving
# Now processing:  75
# Saving
# Now processing:  76
# Saving
# Now processing:  77
# Saving
# Now processing:  78
# thrown out
# Now processing:  79
# Saving
# Now processing:  80
# Saving
# Now processing:  81
# thrown out
# Now processing:  82
# Saving
# Now processing:  83
# Saving
# Now processing:  84
# Saving
# Now processing:  85
# thrown out
# Now processing:  86
# Saving
# Now processing:  87
# Saving
# Now processing:  88
# Saving
# Now processing:  89
# Saving
# Now processing:  90
# Saving
# Now processing:  91
# Saving
# Now processing:  92
# Saving
# Now processing:  93
# Saving
# Now processing:  94
# Saving
# Now processing:  95
# Saving
# Now processing:  96
# Saving
# Now processing:  97
# Saving
# Saving
# Now processing:  311
# Saving
# Now processing:  312
# Saving
# Now processing:  313
# thrown out
# Now processing:  314
# Saving
# Now processing:  315
# Saving
# Now processing:  316
# thrown out
# Now processing:  317
# Saving
# Now processing:  318
# Saving
# Now processing:  319
# Saving
# Now processing:  320
# Saving
# Now processing:  321
# Saving
# Now processing:  322
# Saving
# Now processing:  323
# Saving
# Now processing:  324
# thrown out
# Now processing:  325
# Saving
# Now processing:  326
# Saving
# Now processing:  327
# Saving
# Now processing:  328
# Saving
# Now processing:  329
# Saving
# Now processing:  330
# Saving
# Now processing:  331
# Saving
# Now processing:  332
# Saving
# Now processing:  333
# Saving
# Now processing:  334
# Saving
# Now processing:  335
# Saving
# Now processing:  336
# Saving
# Now processing:  337
# Saving
# Now processing:  338
# Saving
# Now processing:  339
# Saving
# Now processing:  340
# thrown out
# Now processing:  341
# Saving
# Now processing:  342
# Saving
# Now processing:  343
# Saving
# Now processing:  344
# Saving
# Now processing:  345
# Saving
# Now processing:  346
# Saving
# Now processing:  347
# Saving
# Now processing:  348
# Saving
# Now processing:  349
# Saving
# Now processing:  350
# Saving
# Now processing:  351
# Saving
# Now processing:  352
# Saving
# Now processing:  353
# Saving
# Now processing:  354
# Saving
# Now processing:  355
# Saving
# Now processing:  356
# Saving
# Now processing:  357
# Saving
# Now processing:  358
# Saving
# Now processing:  359
# Saving
# Now processing:  360
# Saving
# Now processing:  361
# Saving
# Now processing:  362
# Saving
# Now processing:  363
# Saving
# Now processing:  364
# Saving
# Now processing:  365
# Saving
# Now processing:  366
# Saving
# Now processing:  367
# Saving
# Now processing:  368
# Saving

# %%
## Processing testing daata

# %%
TEST_DATASET_PATH = 'data/testing/'
TRAIN_PROCESSED_DATASET_PATH = 'processed-data/training/'

t1_img_list = sorted(glob.glob(TEST_DATASET_PATH+'/*/*t1.nii'))
t2_img_list = sorted(glob.glob(TEST_DATASET_PATH+'/*/*t2.nii'))
t1ce_img_list = sorted(glob.glob(TEST_DATASET_PATH+'/*/*t1ce.nii'))
flair_img_list = sorted(glob.glob(TEST_DATASET_PATH+'/*/*flair.nii'))

# %%
print(t1_img_list)
# Out:
# ['data/testing/BraTS20_Validation_028/BraTS20_Validation_028_t1.nii', 'data/testing/BraTS20_Validation_029/BraTS20_Validation_029_t1.nii', 'data/testing/BraTS20_Validation_030/BraTS20_Validation_030_t1.nii', 'data/testing/BraTS20_Validation_118/BraTS20_Validation_118_t1.nii', 'data/testing/BraTS20_Validation_119/BraTS20_Validation_119_t1.nii', 'data/testing/BraTS20_Validation_120/BraTS20_Validation_120_t1.nii', 'data/testing/BraTS20_Validation_121/BraTS20_Validation_121_t1.nii', 'data/testing/BraTS20_Validation_122/BraTS20_Validation_122_t1.nii', 'data/testing/BraTS20_Validation_123/BraTS20_Validation_123_t1.nii', 'data/testing/BraTS20_Validation_124/BraTS20_Validation_124_t1.nii', 'data/testing/BraTS20_Validation_125/BraTS20_Validation_125_t1.nii']
